# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

# %%
from using_kde.precision_recall import plot_precision as kde_precision, plot_recall as kde_recall
from using_fastkde.precision_recall import plot_precision as fast_precision, plot_recall as fast_recall
from naive_implementation.precision_recall import plot_precision as naive_precision, plot_recall as naive_recall

# %%
size = 100
y_act = np.linspace(0, 1, num=size)
y_pred = np.linspace(0, 1, num=size) + stats.norm.rvs(loc=0.0, scale=0.3, size=size)

# %%
fig, axes = plt.subplots(1, 3)
fig.set_figwidth(21)
quantiles = [0.05, 0.5, 0.95]
# %timeit naive_precision(y_pred, y_act, ax=axes[0], quantiles=quantiles)
# %timeit kde_precision(y_pred, y_act, ax=axes[1], quantiles=quantiles)
# %timeit fast_precision(y_pred, y_act, ax=axes[2], quantiles=quantiles)
# axes[1].set_xlim([min(y_act), max(y_act)])
# axes[1].set_ylim([0.0, 1.0])
# Out:
# 7.55 ms ± 47.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.04 s ± 4.62 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 147 ms ± 552 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
fig, axes = plt.subplots(1, 3)
fig.set_figwidth(21)
quantiles = [0.05, 0.5, 0.95]
naive_precision(y_pred, y_act, ax=axes[0], quantiles=quantiles)
kde_precision(y_pred, y_act, ax=axes[1], quantiles=quantiles)
fast_precision(y_pred, y_act, ax=axes[2], quantiles=quantiles)
