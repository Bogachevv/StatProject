# %%
import numpy as np
from matplotlib import pyplot as plt
import timeit
import cProfile
import pstats

# %%
from using_kde.precision_recall import plot_precision

# %%
n = 1_000
y_act = np.linspace(0, 1, num=n)
y_pred = y_act + np.random.normal(0.0, 0.1, size=n)

# %%
# %timeit plot_precision(y_act, y_pred)
# Out:
# 12.4 s ± 280 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit plot_precision(y_act, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 get_ipython().run_line_magic('timeit', 'plot_precision(y_act, y_pred)')
#
# File C:\bogachevv\Python\StatProject\venv\lib\site-packages\IPython\core\interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File C:\bogachevv\Python\StatProject\venv\lib\site-packages\IPython\core\magics\execution.py:1166, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1163         if time_number >= 0.2:
#    1164             break
# -> 1166 all_runs = timer.repeat(repeat, number)
#    1167 best = min(all_runs) / number
#    1168 worst = max(all_runs) / number
#
# ...

# %%
with cProfile.Profile() as prof:
    plot_precision(y_act, y_pred)

stats = pstats.Stats(prof)
stats.sort_stats(pstats.SortKey.TIME)
stats.print_stats()
stats.dump_stats('stats_5.prof')
# Out:
#          159798 function calls (154343 primitive calls) in 50.139 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1000   49.659    0.050   49.814    0.050 C:\bogachevv\Python\StatProject\venv\lib\site-packages\scipy\stats\_kde.py:209(evaluate)
# 12155/8112    0.091    0.000    0.259    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      1000    0.055    0.000   50.008    0.050 C:\bogachevv\Python\StatProject\using_kde\precision_recall.py:8(get_cdf)
#      1003    0.040    0.000    0.040    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#      1000    0.037    0.000    0.058    0.000 C:\bogachevv\Python\StatProject\venv\lib\site-packages\numpy\linalg\linalg.py:679(cholesky)
#         1    0.015    0.015   50.139   50.139 C:\bogachevv\Python\StatProject\using_kde\precision_recall.py:35(plot_precision)
# ...
